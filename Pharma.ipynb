# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('indian_pharmaceutical_products_clean.csv')
data.head()
# Out:
#    product_id                brand_name                          manufacturer  \
# 0           1  Augmentin 625 Duo Tablet  Glaxo SmithKline Pharmaceuticals Ltd
# 1           2       Azithral 500 Tablet           Alembic Pharmaceuticals Ltd
# 2           3          Ascoril LS Syrup          Glenmark Pharmaceuticals Ltd
# 3           4      Allegra 120mg Tablet                      Sanofi India Ltd
# 4           5            Avil 25 Tablet                      Sanofi India Ltd
#
#    price_inr  is_discontinued dosage_form  pack_size pack_unit  \
# 0     223.42            False      tablet       10.0     strip
# 1     132.36            False      tablet        5.0     strip
# 2     118.00            False       syrup      100.0    bottle
# 3     218.81            False      tablet       10.0     strip
# 4      10.96            False      tablet       15.0     strip
#
#    num_active_ingredients primary_ingredient primary_strength  \
# ...

# %%
data.columns
# Out:
# Index(['product_id', 'brand_name', 'manufacturer', 'price_inr',
#        'is_discontinued', 'dosage_form', 'pack_size', 'pack_unit',
#        'num_active_ingredients', 'primary_ingredient', 'primary_strength',
#        'active_ingredients', 'therapeutic_class', 'packaging_raw',
#        'manufacturer_raw'],
#       dtype='object')

# %%
data.shape
# Out:
# (253973, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253973 entries, 0 to 253972
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   product_id              253973 non-null  int64
#  1   brand_name              253973 non-null  object
#  2   manufacturer            253973 non-null  object
#  3   price_inr               253973 non-null  float64
#  4   is_discontinued         253973 non-null  bool
#  5   dosage_form             253973 non-null  object
#  6   pack_size               231643 non-null  float64
#  7   pack_unit               231643 non-null  object
#  8   num_active_ingredients  253973 non-null  int64
#  9   primary_ingredient      253973 non-null  object
#  10  primary_strength        228775 non-null  object
#  11  active_ingredients      253973 non-null  object
#  12  therapeutic_class       253973 non-null  object
#  13  packaging_raw           253973 non-null  object
# ...

# %%
data.describe()
# Out:
#           product_id      price_inr      pack_size  num_active_ingredients
# count  253973.000000  253973.000000  231643.000000           253973.000000
# mean   126987.000000     270.530844      18.988871                1.441893
# std     73315.834296    3029.584134      36.717320                0.496795
# min         1.000000       0.000000       1.000000                1.000000
# 25%     63494.000000      48.000000      10.000000                1.000000
# 50%    126987.000000      79.000000      10.000000                1.000000
# 75%    190480.000000     140.000000      10.000000                2.000000
# max    253973.000000  436000.000000    5000.000000                5.000000

# %%
data.isnull().sum()
# Out:
# product_id                    0
# brand_name                    0
# manufacturer                  0
# price_inr                     0
# is_discontinued               0
# dosage_form                   0
# pack_size                 22330
# pack_unit                 22330
# num_active_ingredients        0
# primary_ingredient            0
# primary_strength          25198
# active_ingredients            0
# therapeutic_class             0
# packaging_raw                 0
# manufacturer_raw              0
# dtype: int64

# %% [markdown]
# # Handle missing values after understand the dataset

# %%
data[data['primary_strength'].isnull()]
# Out:
#         product_id                      brand_name  \
# 12              13                   Anovate Cream
# 15              16                  Arkamin Tablet
# 25              26         Asthalin 100mcg Inhaler
# 35              36           Alkasol Oral Solution
# 39              40          Arachitol 6L Injection
# ...            ...                             ...
# 253810      253811        Zypfresh 0.2% Mouth Wash
# 253825      253826          Zacroli 0.03% Ointment
# 253826      253827  Zatrocob P 750mcg/75mg Capsule
# 253887      253888  Zylocab PG 750mcg/75mg Capsule
# 253972      253973       Zyvocol 1% Dusting Powder
#
#                          manufacturer  price_inr  is_discontinued dosage_form  \
# 12                            USV Ltd     134.20            False       cream
# 15        Torrent Pharmaceuticals Ltd      72.65            False      tablet
# 25                          Cipla Ltd     157.85            False     inhaler
# ...

# %%
data['primary_ingredient'].value_counts()
# Out:
# primary_ingredient
# Cefixime                          8992
# Domperidone                       8869
# Aceclofenac                       8683
# Amoxycillin                       8550
# Ofloxacin                         6768
#                                   ...
# Pegaptanib                           1
# Gynaecological Products              1
# Neisseria Meningitidis Group A       1
# Pramoxine                            1
# Amtolmetin Guacil                    1
# Name: count, Length: 1586, dtype: int64

# %%
data['dosage_form'].value_counts()
# Out:
# dosage_form
# tablet        152586
# injection      32044
# capsule        22265
# syrup          16747
# suspension      9179
# drops           5282
# cream           5071
# other           4503
# solution        1808
# gel             1687
# ointment        1669
# powder           377
# spray            366
# inhaler          267
# respules         122
# Name: count, dtype: int64

# %%
# checks null values of primary strength where primary ingredient is Amoxycillin
data[(data['primary_ingredient'] == 'Amoxycillin') & (data['primary_strength'].isnull())]
# Out:
#         product_id                  brand_name  \
# 7260          7261         Augmentox Dry Syrup
# 17899        17900         Afdimoxin Dry Syrup
# 23975        23976              Amodux Capsule
# 24202        24203            Alcloxd  Capsule
# 27472        27473           Bacnil LB Capsule
# 51343        51344           Capcillin Capsule
# 52224        52225  Claventin Forte Suspension
# 52599        52600            Clomoxil Capsule
# 57934        57935                CEPMOX SYRUP
# 78544        78545          Ecoclav Duo Tablet
# 87629        87630     Flemoxin CV Plus Tablet
# 100593      100594          Gramimox-CV Tablet
# 100869      100870          Gramipen-CV Tablet
# 110701      110702            Imox Clo Capsule
# 125180      125181                LC Mox Syrup
# 138639      138640         Moxibond Oral Drops
# 139778      139779       Moxynek-CV 625 Tablet
# 141081      141082          Monomox DX Capsule
# 143641      143642            MEDMOX DX TABLET
# ...

# %%
check = data[(data['primary_ingredient'] == 'Amoxycillin') & (data['dosage_form'] == 'tablet')]
check[['brand_name', 'dosage_form','primary_ingredient', 'primary_strength','num_active_ingredients']]
# Out:
#                            brand_name dosage_form primary_ingredient  \
# 0            Augmentin 625 Duo Tablet      tablet        Amoxycillin
# 6                Amoxyclav 625 Tablet      tablet        Amoxycillin
# 91          Augmentin 1000 Duo Tablet      tablet        Amoxycillin
# 102              Augmentin 375 Tablet      tablet        Amoxycillin
# 190               Almox-CV 625 Tablet      tablet        Amoxycillin
# ...                               ...         ...                ...
# 253680         Zofmox 250mg Tablet DT      tablet        Amoxycillin
# 253806  Zabimox-CV 250mg/125mg Tablet      tablet        Amoxycillin
# 253927     Zocmoxy 500mg/125mg Tablet      tablet        Amoxycillin
# 253951   Ziomox CV 500mg/125mg Tablet      tablet        Amoxycillin
# 253952      Zwitermox 250mg Tablet DT      tablet        Amoxycillin
#
#        primary_strength  num_active_ingredients
# 0                 500mg                       2
# ...

# %%
mask = (
    (data['primary_ingredient'] == 'Amoxycillin') &
    (data['dosage_form'].isin(['tablet','capsule'])) &
    (data['primary_strength'].isnull()))

data.loc[mask, 'primary_strength'] = '500mg'

# %%
mask = (
    (data['primary_ingredient'] == 'Amoxycillin') &
    (data['dosage_form'].isin(['syrup','suspension'])) &
    (data['primary_strength'].isnull()))

data.loc[mask, 'primary_strength'] = '200mg'

# %%
mask = (
    (data['primary_ingredient'] == 'Amoxycillin') &
    (data['dosage_form'].isin(['drops'])) &
    (data['primary_strength'].isnull()))

data.loc[mask, 'primary_strength'] = 'Unknown'

# %%
data[(data['primary_ingredient'] == 'Amoxycillin') & (data['primary_strength'].isnull())]
# Out:
# Empty DataFrame
# Columns: [product_id, brand_name, manufacturer, price_inr, is_discontinued, dosage_form, pack_size, pack_unit, num_active_ingredients, primary_ingredient, primary_strength, active_ingredients, therapeutic_class, packaging_raw, manufacturer_raw]
# Index: []

# %%
data[ (data['primary_ingredient'] == 'Cefixime') & (data['primary_strength'].isnull())]
# Out:
#         product_id                brand_name  \
# 3465          3466          Azidep CX Tablet
# 17053        17054       Abcef AZ Kid Tablet
# 36536        36537            Ceme CV Tablet
# 41934        41935             Cfx CV Tablet
# 43074        43075        Cefifurt CV Tablet
# 44106        44107            Cefolin Tablet
# 44235        44236         Cefifurt O Tablet
# 45852        45853           Cefaking Tablet
# 46193        46194           Cedro CV Tablet
# 47393        47394        Cifadin Clv Tablet
# 49190        49191          Cefpar CV Tablet
# 50743        50744          Cefiyug O Tablet
# 51405        51406        Cefistar Dry Syrup
# 55459        55460         Cefly O Dry Syrup
# 78882        78883               EM Infusion
# 80135        80136  Excef LB Oral Suspension
# 87863        87864         Fexinex Tablet DT
# 88153        88154             Fax TZ Tablet
# 92180        92181       Fax TZ Forte Tablet
# 138748      138749         Myfexim CV Tablet
# ...

# %%
mask = (
    (data['primary_ingredient'] == 'Cefixime') &
    (data['dosage_form'].isin(['tablet'])) &
     (data['primary_strength'].isnull()))
    
data.loc[mask,'primary_strength'] = '500mg'

# %%
mask = (
    (data['primary_ingredient'] == 'Cefixime') &
    (data['dosage_form'].isin(['syrup','suspension'])) &
    (data['primary_strength'].isnull()))

data.loc[mask,'primary_strength'] = '200mg'

# %%
mask = (
    (data['primary_ingredient'] == 'Cefixime') &
    (data['dosage_form'].isin(['drops','other'])) &
    (data['primary_strength'].isnull()))

data.loc[mask,'primary_strength'] = 'Unknown'

# %%
data[ (data['primary_ingredient'] == 'Cefixime') & (data['primary_strength'].isnull())]
# Out:
# Empty DataFrame
# Columns: [product_id, brand_name, manufacturer, price_inr, is_discontinued, dosage_form, pack_size, pack_unit, num_active_ingredients, primary_ingredient, primary_strength, active_ingredients, therapeutic_class, packaging_raw, manufacturer_raw]
# Index: []

# %%
# almost drops values are null, so fill with unknown 
data[data['dosage_form'] == 'drops'].isnull().sum()
# Out:
# product_id                   0
# brand_name                   0
# manufacturer                 0
# price_inr                    0
# is_discontinued              0
# dosage_form                  0
# pack_size                   16
# pack_unit                   16
# num_active_ingredients       0
# primary_ingredient           0
# primary_strength          3851
# active_ingredients           0
# therapeutic_class            0
# packaging_raw                0
# manufacturer_raw             0
# dtype: int64

# %%
mask = (
    (data['dosage_form'].isin(['drops'])) & 
    (data['primary_strength'].isnull()))
data.loc[mask, 'primary_strength'] = 'Unknown'

# %%
data[data['dosage_form'] == 'drops'].isnull().sum()
# Out:
# product_id                 0
# brand_name                 0
# manufacturer               0
# price_inr                  0
# is_discontinued            0
# dosage_form                0
# pack_size                 16
# pack_unit                 16
# num_active_ingredients     0
# primary_ingredient         0
# primary_strength           0
# active_ingredients         0
# therapeutic_class          0
# packaging_raw              0
# manufacturer_raw           0
# dtype: int64

# %%
mask = (
    (data['dosage_form'].isin(['tablet','capsule'])) &
    (data['primary_strength'].isnull()))

data.loc[mask,'primary_strength'] = '500mg'

# %%
mask = (
    (data['dosage_form'].isin(['syrup','suspension'])) &
    (data['primary_strength'].isnull()))

data.loc[mask,'primary_strength'] = '200mg'

# %%
mask = (
    (data['dosage_form'].isin(['injection'])) &
    (data['primary_strength'].isnull()))

data.loc[mask,'primary_strength'] = '250mg'

# %%
# see where cream value
data[data['dosage_form'] == 'cream']
# Out:
#         product_id          brand_name                   manufacturer  \
# 12              13       Anovate Cream                        USV Ltd
# 52              53      Anobliss Cream  Samarth Life Sciences Pvt Ltd
# 104            105        Acivir Cream                      Cipla Ltd
# 111            112   Aziderm 20% Cream                 Micro Labs Ltd
# 114            115  Ano Metrogyl Cream               Lekar Pharma Ltd
# ...            ...                 ...                            ...
# 252591      252592        Zinsto Cream                Imed Healthcare
# 252745      252746    Zolrico 1% Cream         Enrico Pharmaceuticals
# 253132      253133      Zeomycin Cream                  Zenicure Labs
# 253315      253316     Zexosis M Cream       KAINOSIS PHARMACEUTICALS
# 253401      253402        Zygter Cream    Encore Pharmaceuticals Inc.
#
#         price_inr  is_discontinued dosage_form  pack_size pack_unit  \
# ...

# %%
data[data['dosage_form'] == 'cream'].isnull().sum()
# Out:
# product_id                   0
# brand_name                   0
# manufacturer                 0
# price_inr                    0
# is_discontinued              0
# dosage_form                  0
# pack_size                    5
# pack_unit                    5
# num_active_ingredients       0
# primary_ingredient           0
# primary_strength          4904
# active_ingredients           0
# therapeutic_class            0
# packaging_raw                0
# manufacturer_raw             0
# dtype: int64

# %% [markdown]
# ### to check values are not null

# %%
data[
    (data['dosage_form'] == 'cream') &
    (data['primary_strength'].notnull())
]
# Out:
#         product_id               brand_name  \
# 758            759             Auxerg Cream
# 874            875             Auxerg Cream
# 1492          1493           Amortive Cream
# 4647          4648           Amortive Cream
# 8665          8666        Azokid 0.1% Cream
# ...            ...                      ...
# 231280      231281         Uniderm NF Cream
# 232321      232322      Ucecort 0.10% Cream
# 233769      233770              Vimet Cream
# 233908      233909  Vagimoist Vaginal Cream
# 247341      247342          Zovate GN Cream
#
#                                 manufacturer  price_inr  is_discontinued  \
# 758                                Cipla Ltd     242.00            False
# 874                                Cipla Ltd     185.00             True
# 1492                Rockmed Pharma Pvt. Ltd.     330.00            False
# 4647                Rockmed Pharma Pvt. Ltd.     130.00            False
# ...

# %%
mask = (
    (data['dosage_form'].isin(['cream'])) &
    (data['primary_strength'].isnull()))
data.loc[mask, 'primary_strength'] = '5mg'

# %%
data[data['dosage_form'] =='other'].isnull().sum()
# Out:
# product_id                   0
# brand_name                   0
# manufacturer                 0
# price_inr                    0
# is_discontinued              0
# dosage_form                  0
# pack_size                  707
# pack_unit                  707
# num_active_ingredients       0
# primary_ingredient           0
# primary_strength          2479
# active_ingredients           0
# therapeutic_class            0
# packaging_raw                0
# manufacturer_raw             0
# dtype: int64

# %%
# fill all other values with Unknown
mask = (
    (data['dosage_form'].isin(['other'])) &
    (data['primary_strength'].isnull()))
data.loc[mask,'primary_strength'] = 'Unknown'

# %%
data[data['dosage_form'] == 'solution'].isnull().sum()
# Out:
# product_id                   0
# brand_name                   0
# manufacturer                 0
# price_inr                    0
# is_discontinued              0
# dosage_form                  0
# pack_size                   48
# pack_unit                   48
# num_active_ingredients       0
# primary_ingredient           0
# primary_strength          1158
# active_ingredients           0
# therapeutic_class            0
# packaging_raw                0
# manufacturer_raw             0
# dtype: int64

# %%
data[(data['dosage_form'] == 'solution') & (data['primary_strength'].notnull())]
# Out:
#         product_id                                         brand_name  \
# 236            237                       Asthalin Respirator Solution
# 406            407               Alkamax MB Alkamax MB6 Oral Solution
# 672            673  Alkashot B6 Oral Solution Delicious Pineapple ...
# 918            919                                    Alcaft Eye Drop
# 1172          1173                                Anasure 2% Solution
# ...            ...                                                ...
# 250714      250715                                  Zobilan Injection
# 251709      251710                             Zoycid-O Oral Solution
# 252220      252221                       Zodilac 3.35gm Oral Solution
# 252308      252309                             Zerocary Oral Solution
# 253584      253585                                Zerly Oral Solution
#
#                                  manufacturer  price_inr  is_discontinued  \
# ...

# %%
mask = (
    (data['dosage_form'].isin(['solution'])) &
    (data['primary_strength'].isnull()))
data.loc[mask,'primary_strength'] = '500mg'

# %%
data[data['dosage_form'] == 'gel']
# Out:
#         product_id                 brand_name  \
# 88              89               Adaferin Gel
# 200            201         Acnesol A Nano Gel
# 222            223                Acnesol Gel
# 245            246        Adalene Nanogel Gel
# 255            256                Atonide Gel
# ...            ...                        ...
# 251398      251399             Zybol Oral Gel
# 251649      251650         Zeodent Dental Gel
# 252167      252168  Zoney Oral Gel Sugar Free
# 252450      252451          Zovenac 1.16% Gel
# 252479      252480                Zeromac Gel
#
#                             manufacturer  price_inr  is_discontinued  \
# 88                Galderma India Pvt Ltd      284.0            False
# 200        Systopic Laboratories Pvt Ltd      206.0            False
# 222        Systopic Laboratories Pvt Ltd       87.0            False
# 245                         Zydus Cadila      325.0            False
# ...

# %%
data[data['dosage_form'] == 'gel'].isnull().sum()
# Out:
# product_id                   0
# brand_name                   0
# manufacturer                 0
# price_inr                    0
# is_discontinued              0
# dosage_form                  0
# pack_size                    8
# pack_unit                    8
# num_active_ingredients       0
# primary_ingredient           0
# primary_strength          1435
# active_ingredients           0
# therapeutic_class            0
# packaging_raw                0
# manufacturer_raw             0
# dtype: int64

# %%
mask = (
    (data['dosage_form'].isin(['gel'])) &
    (data['primary_strength'].isnull()))
data.loc[mask,'primary_strength'] = '20g'

# %%
data[
    (data['dosage_form'] == 'ointment') &
    (data['primary_strength'].notnull())
]
# Out:
#         product_id                 brand_name  \
# 803            804       Addex 500mg Ointment
# 3563          3564    Anchlor-DX Eye Ointment
# 6451          6452        Altargo 1% Ointment
# 8133          8134         Aldine 5% Ointment
# 12184        12185  Acromus 0.1% Eye Ointment
# ...            ...                        ...
# 247063      247064            Zylo-P Ointment
# 247282      247283      Zuvendine 5% Ointment
# 247374      247375           Zovi 5% Ointment
# 248073      248074        Zypovid 5% Ointment
# 251415      251416        Zypovid 5% Ointment
#
#                                  manufacturer  price_inr  is_discontinued  \
# 803     Franco-Indian Pharmaceuticals Pvt Ltd     175.00            False
# 3563            Nri Vision Care India Limited      75.00            False
# 6451     Glaxo SmithKline Pharmaceuticals Ltd     120.00             True
# 8133                                   Abbott      15.00             True
# ...

# %%
mask = (
    (data['dosage_form'].isin(['ointment'])) &
    (data['primary_strength'].isnull()))
data.loc[mask,'primary_strength'] = '20g'

# %%
data[data['dosage_form'] == 'powder'].isnull().sum()
# Out:
# product_id                  0
# brand_name                  0
# manufacturer                0
# price_inr                   0
# is_discontinued             0
# dosage_form                 0
# pack_size                   7
# pack_unit                   7
# num_active_ingredients      0
# primary_ingredient          0
# primary_strength          256
# active_ingredients          0
# therapeutic_class           0
# packaging_raw               0
# manufacturer_raw            0
# dtype: int64

# %%
data[
    (data['dosage_form'] == 'powder') &
    (data['primary_strength'].notnull())
]
# Out:
#         product_id                                     brand_name  \
# 3104          3105             Argitrust Sachet Orange Sugar Free
# 25806        25807                                Betadine Powder
# 26578        26579  Biozora Powder Orange and Vanilla Gluten Free
# 26956        26957                        Burnheal Dusting Powder
# 28162        28163                               Bestosulf Powder
# ...            ...                                            ...
# 241813      241814                          Winogut Sachet Orange
# 241822      241823                            WOCKADINE 5% POWDER
# 248005      248006                             Zedott Plus Powder
# 248464      248465                                 Zovi 5% Powder
# 251787      251788                            Zegecid 40mg Powder
#
#                                manufacturer  price_inr  is_discontinued  \
# 3104                  Daemon Pharma Pvt Ltd      40.00            False
# ...

# %%
mask = (
    (data['dosage_form'].isin(['powder'])) &
    (data['primary_strength'].isnull()))
data.loc[mask,'primary_strength'] = '200g'

# %%
data['primary_strength'].fillna('Unknown', inplace = True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_60\2049328531.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['primary_strength'].fillna('Unknown', inplace = True)

# %%
data.isnull().sum()
# Out:
# product_id                    0
# brand_name                    0
# manufacturer                  0
# price_inr                     0
# is_discontinued               0
# dosage_form                   0
# pack_size                 22330
# pack_unit                 22330
# num_active_ingredients        0
# primary_ingredient            0
# primary_strength              0
# active_ingredients            0
# therapeutic_class             0
# packaging_raw                 0
# manufacturer_raw              0
# dtype: int64

# %% [markdown]
# ## Now fill pack_size

# %%
data['pack_size'].fillna('Unknown', inplace = True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_60\1855613534.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['pack_size'].fillna('Unknown', inplace = True)
# C:\Users\dell\AppData\Local\Temp\ipykernel_60\1855613534.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data['pack_size'].fillna('Unknown', inplace = True)

# %%
data.isnull().sum()
# Out:
# product_id                    0
# brand_name                    0
# manufacturer                  0
# price_inr                     0
# is_discontinued               0
# dosage_form                   0
# pack_size                     0
# pack_unit                 22330
# num_active_ingredients        0
# primary_ingredient            0
# primary_strength              0
# active_ingredients            0
# therapeutic_class             0
# packaging_raw                 0
# manufacturer_raw              0
# dtype: int64

# %% [markdown]
# ## Handle pack_unit column mow

# %%
data['pack_unit'].value_counts()
# Out:
# pack_unit
# strip     172122
# bottle     33772
# ml         14790
# tube        8241
# units       1424
# gm          1294
# Name: count, dtype: int64

# %%
data['dosage_form'].value_counts()
# Out:
# dosage_form
# tablet        152586
# injection      32044
# capsule        22265
# syrup          16747
# suspension      9179
# drops           5282
# cream           5071
# other           4503
# solution        1808
# gel             1687
# ointment        1669
# powder           377
# spray            366
# inhaler          267
# respules         122
# Name: count, dtype: int64

# %%
mask = (
    (data['dosage_form'].isin(['tablet','capsule'])) &
    (data['pack_unit'].isnull()))
data.loc[mask,'pack_unit'] = 'strip'

# %%
mask = (
    (data['dosage_form'].isin(['syrup','suspension','solution','inhaler','powder','spray'])) &
    (data['pack_unit'].isnull()))
data.loc[mask,'pack_unit'] = 'bottle'

# %%
mask = (
    (data['dosage_form'].isin(['drops'])) &
    (data['pack_unit'].isnull()))
data.loc[mask,'pack_unit'] = 'ml'

# %%
mask = (
    (data['dosage_form'].isin(['injection','respules'])) &
    (data['pack_unit'].isnull()))
data.loc[mask,'pack_unit'] = 'ml'

# %%
mask = (
    (data['dosage_form'].isin(['ointment','cream','gel'])) &
    (data['pack_unit'].isnull()))

data.loc[mask, 'pack_unit'] = 'tube'

# %%
mask = (
    (data['dosage_form'].isin(['other'])) &
    (data['pack_unit'].isnull()))

data.loc[mask, 'pack_unit'] = 'Unknown'

# %%
data.isnull().sum()
# Out:
# product_id                0
# brand_name                0
# manufacturer              0
# price_inr                 0
# is_discontinued           0
# dosage_form               0
# pack_size                 0
# pack_unit                 0
# num_active_ingredients    0
# primary_ingredient        0
# primary_strength          0
# active_ingredients        0
# therapeutic_class         0
# packaging_raw             0
# manufacturer_raw          0
# dtype: int64

# %% [markdown]
# ## Cleaning and handle missing data phase finished

# %%
# save the file
data.to_csv('updated_pharma_data.csv', index=False)

# %%
data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 253968    False
# 253969    False
# 253970    False
# 253971    False
# 253972    False
# Length: 253973, dtype: bool
